# %%
import pandas as pd

# %%
#Define DataFrame: questions and correct answers in it.
competitionDataFrame = pd.DataFrame({
    "questions": ["Avrupa Futbol Federasyonları Birliği'nin kısaltılmışı nedir?",
                  "Dünyanın en büyük deniz kazalarından biri-1912 yılında 1.550 kişiye mezar olan ünlü transatlantiğin adı nedir?",
                  "Düğünlerde şölenlerde davulla birlikte çalınan enstruman hangisidir?",
                  "Suçluların yakalanmasında kullanılan en önemli delillerden biridir, suçlunun geride bıraktığı iz?",
                  "Haberleşmenin eski dildeki adı nedir?",
                  "Lakin ve fakatın eş anlamlısı",
                  "Telli çalgılarda sazların en kalın teli",
                  "Belli bir süre eğitimi tamamladıktan sonra alınan, sir okul ya da eğitim kurumu tarafından verilen belgenin adı?",
                  "Japonların geleneksel güreşine ne ad verilir?",
                  "Türkiye'nin gül ve gül yağı üretiminde dünya çapındaki şehrimiz neresidir?"],
    "correctAnswers": ["UEFA","Titanik","Zurna","Parmak İzi","Muhabere","Ama","Bam Teli","Diploma","Sumo","Isparta"]
})

#Check whether the user answer is true or not
def checkAnswer(m):
    if competitionDataFrame.correctAnswers[x] == m:
        print("Your answer is true")
        return True
    else:
        print("Your answer is false")

# %%
totalScore = 0
print("Welcome to the competition...You will answer 10 questions...Let's get started...")
x=0
while x<=9:
    #Ask the questions to the user
    print(f"\n Soru {x+1} :")
    print(competitionDataFrame.questions[x])
    #Get the user answer
    userAnswer = input("Please write your answer:  ")
    
    #Calculate the total score
    if checkAnswer(userAnswer) == True:
        global totalScore
        totalScore += 10
        print(f"Current total score: {totalScore}")
    else:
        print(f"Current total score is still: {totalScore}")           
        
    x+=1
    
#Write result
print("\n\n The competition is over")
print(f"\n Result Score: {totalScore}") 
if totalpuan>50:
    print("\n Congratulations...You are successful...")
else:
    print("\n Unfortunately...You are unsuccessful...")
# Out:
# Welcome to the competition...You will answer 10 questions...Let's get started...
#
#  Soru 1 :
# Avrupa Futbol Federasyonları Birliği'nin kısaltılmışı nedir?
# Please write your answer:  l
# Your answer is false
# Current total score is still: 0
#
#  Soru 2 :
# Dünyanın en büyük deniz kazalarından biri-1912 yılında 1.550 kişiye mezar olan ünlü transatlantiğin adı nedir?
# Please write your answer:  d
# Your answer is false
# Current total score is still: 0
#
#  Soru 3 :
# Düğünlerde şölenlerde davulla birlikte çalınan enstruman hangisidir?
# Please write your answer:  d
# Your answer is false
# Current total score is still: 0
#
#  Soru 4 :
# Suçluların yakalanmasında kullanılan en önemli delillerden biridir, suçlunun geride bıraktığı iz?
# Please write your answer:  d
# Your answer is false
# Current total score is still: 0
#
#  Soru 5 :
# Haberleşmenin eski dildeki adı nedir?
# Please write your answer:  d
# Your answer is false
# Current total score is still: 0
#
#  Soru 6 :
# ...
