# %%
import pandas as pd
import numpy as np

# %%
k1 = pd.DataFrame({
    "studentName":["",""],
    "midtermGrade":["",""],
    "projectGrade":["",""],
    "finalGrade":["",""],
    "passingGrade":["",""],

})

def check1(a):
    while True:
        try:
            if a >= 0 and a <= 100:
                return a
            
            elif a<0 or a>100:
                print("0-100 arasi gir!!")
                check1(a)
                
            elif a == str(a):
                print("harf girdin düzelt!!")

        except:
            print("integer sayi gir!!")

# %%
#get students name
for i in range(2):
    print(f"\n Enter for student{i+1}: ")
    k1.studentName[i] = str(input("Name:   "))
    
    #get grades
    k1.midtermGrade[i] = int(input("Midterm Grade:   "))
    check1(k1.midtermGrade[i])
    k1.projectGrade[i] = int(input("Project Grade:   "))
    k1.finalGrade[i] = int(input("Final Grade:     "))
    
    #calculate passing grade
    k1.passingGrade[i] = (k1.midtermGrade[i]*0.3 + k1.projectGrade[i]*0.3 + k1.finalGrade[i]*0.4)
    
#sort the table according to passing grades
yenik1 = k1.sort_values('passingGrade', ascending=False)

#print the sorted table
print(yenik1)
# Out:
#  Enter for student1:
# Name:   a
# Midterm Grade:   200
# 0-100 arasi gir!!
# 0-100 arasi gir!!
# 0-100 arasi gir!!
# 0-100 arasi gir!!
# 0-100 arasi gir!!
# 0-100 arasi gir!!
# 0-100 arasi gir!!
# 0-100 arasi gir!!
# 0-100 arasi gir!!
# 0-100 arasi gir!!
# 0-100 arasi gir!!
# 0-100 arasi gir!!
# 0-100 arasi gir!!
# 0-100 arasi gir!!
# 0-100 arasi gir!!
# 0-100 arasi gir!!
# 0-100 arasi gir!!
# 0-100 arasi gir!!
# 0-100 arasi gir!!
# 0-100 arasi gir!!
# 0-100 arasi gir!!
# 0-100 arasi gir!!
# 0-100 arasi gir!!
# 0-100 arasi gir!!
# 0-100 arasi gir!!
# 0-100 arasi gir!!
# 0-100 arasi gir!!
# 0-100 arasi gir!!
# 0-100 arasi gir!!
# 0-100 arasi gir!!
# 0-100 arasi gir!!
# 0-100 arasi gir!!
# 0-100 arasi gir!!
# 0-100 arasi gir!!
# 0-100 arasi gir!!
# 0-100 arasi gir!!
# 0-100 arasi gir!!
# 0-100 arasi gir!!
# 0-100 arasi gir!!
# 0-100 arasi gir!!
# 0-100 arasi gir!!
# 0-100 arasi gir!!
# 0-100 arasi gir!!
# 0-100 arasi gir!!
# 0-100 arasi gir!!
# 0-100 arasi gir!!
# 0-100 arasi gir!!
# ...

# %%
def getMidtermGrade():
    k1.midtermGrade[i] = int(input("Midterm Grade:   "))
    g = k1.midtermGrade[i]
    if g >= 0 and g <= 100:
        return g
    else:
        print("0-100 arasi gir!!")
        getMidtermGrade()
        
def getProjectGrade():
    k1.projectGrade[i] = int(input("Project Grade:   "))
    g = k1.projectGrade[i]
    if g >= 0 and g <= 100:
        return g
    else:
        print("0-100 arasi gir!!")
        getProjectGrade()
        
def getFinalGrade():
    k1.finalGrade[i] = int(input("Final Grade:   "))
    g = k1.finalGrade[i]
    if g >= 0 and g <= 100:
        return g
    else:
        print("0-100 arasi gir!!")
        getFinalGrade()
        
#calculate passing grade        
def calculatePassingGrade():
     k1.passingGrade[i] = (k1.midtermGrade[i]*0.3 + k1.projectGrade[i]*0.3 + k1.finalGrade[i]*0.4)

# %%
#get students name
for i in range(2):
    print(f"\n Enter for student{i+1}: ")
    k1.studentName[i] = str(input("Name:   "))

    getMidtermGrade()
    getProjectGrade()
    getFinalGrade()
    
    calculatePassingGrade()   
                                       
#sort the table according to passing grades
yenik1 = k1.sort_values('passingGrade', ascending=False)

#print the sorted table
print(yenik1)
